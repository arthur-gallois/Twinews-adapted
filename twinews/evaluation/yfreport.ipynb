# %% [markdown]
# This notebook allow you to print results of models in tables

# %%
import os ; os.environ["CUDA_VISIBLE_DEVICES"] = ""

# %%
from systemtools.hayj import *
from systemtools.location import *
from systemtools.basics import *
from systemtools.file import *
from systemtools.printer import *
from twinews.utils import *
from twinews.evaluation.utils import *

# %%
df = printReport\
(
    model='lda',
    splitVersion=2,
    noSubsampling=True,
    metaFilter=\
    {
        # "implementation": "gensim-lda",
    },
    metricsFilter=None, # {'ndcg', 'ndcg@10'},
    sortBy='ndcg',
)
# Out:
# These values are common to all rows:
#
# 	- useExtraNews: False
# 	- lowercase: True
# 	- model: lda
# 	- ldaLearningMethod: online
# 	- ldaLearningDecay: 0.7
# 	- splitVersion: 2
# 	- maxUsers: None
# 	- maxDF: 300
#            id   distance  doLemmatization historyRef implementation  \
# 10  lda-d1220     cosine            False        0.3     gensim-lda
# 12  lda-af807     cosine            False         30     gensim-lda
# 15  lda-759de     cosine            False        0.6     gensim-lda
# 6   lda-64d0c     cosine            False        1.0     gensim-lda
# 4   lda-2fa8e  euclidean            False        0.3     gensim-lda
# 3   lda-b849e     cosine            False        0.3     gensim-lda
# 7   lda-7786b     cosine             True        0.3     gensim-lda
# 2   lda-d3b82     cosine            False        0.3     gensim-lda
# 8   lda-94782     cosine            False          3     gensim-lda
# 14  lda-186ce     cosine            False          1     gensim-lda
# 0   lda-de387     cosine            False        0.5    sklearn-lda
# 11  lda-51ce2     cosine            False        0.3     gensim-lda
# 5   lda-aa8d5     cosine             True        0.3     gensim-lda
# 13  lda-b637b     cosine            False        0.5     gensim-lda
# 9   lda-34076     cosine            False        0.3     gensim-lda
# 1   lda-71511     cosine             True        0.3     gensim-lda
#
#     ldaLearningOffset  maxDocuments  maxIter   minDF  nbTopics  useTFIDF  \
# 10                1.0        100000       60  0.0005       100     False
# 12                1.0         10000       60  0.0005       100     False
# 15                1.0         10000       60  0.0005       100     False
# 6                 1.0         10000       60  0.0005       100     False
# 4                 1.0         10000       60  0.0005       100     False
# 3                 1.0         10000       60  0.0005       300     False
# 7                 1.0         10000       60  0.0005       100     False
# 2                 1.0         10000       60  0.0005       100     False
# 8                 1.0         10000       60  0.0005       100     False
# 14                1.0         10000       60  0.0005       100     False
# 0                 1.0           500        2  0.0020        30     False
# 11               10.0         10000       60  0.0005       100     False
# 5                 1.0          1000       30  0.0005        30      True
# 13                1.0         10000       30  0.0005       100      True
# 9                 1.0         10000       60  0.0005       100      True
# 1                 1.0         10000       30  0.0005        30      True
#
#          map       mrr      ndcg   ndcg@10  ndcg@100      p@10     p@100
# 10  0.131120  0.274326  0.386483  0.157042  0.287863  0.104363  0.040735
# 12  0.124114  0.280166  0.379418  0.157717  0.268787  0.102465  0.036118
# 15  0.119143  0.273456  0.374841  0.151466  0.264193  0.099220  0.036128
# 6   0.120190  0.274310  0.374784  0.152779  0.260727  0.099453  0.035244
# 4   0.108196  0.254482  0.361689  0.137830  0.245750  0.091047  0.034073
# 3   0.105073  0.244526  0.356511  0.132101  0.236323  0.086011  0.033017
# 7   0.103803  0.235455  0.355055  0.127154  0.236139  0.084533  0.033966
# 2   0.101780  0.230012  0.353350  0.125064  0.233837  0.083030  0.033504
# 8   0.089304  0.197237  0.338766  0.104603  0.214563  0.068727  0.031314
# 14  0.071902  0.158148  0.316092  0.080907  0.181601  0.054863  0.027768
# 0   0.060916  0.160540  0.304137  0.075479  0.160254  0.051217  0.024316
# 11  0.044310  0.108344  0.280176  0.046566  0.124540  0.033776  0.021236
# 5   0.033513  0.089155  0.258672  0.037511  0.090241  0.025803  0.014548
# 13  0.032071  0.086638  0.256728  0.035279  0.087218  0.023961  0.013872
# 9   0.029006  0.076534  0.253381  0.029551  0.083380  0.021019  0.014060
# 1   0.018146  0.044536  0.231347  0.015159  0.046990  0.010984  0.008303

# %%
df = printReport\
(
    model='nmf',
    splitVersion=2,
    noSubsampling=True,
    metaFilter=\
    {
        # "implementation": "gensim-lda",
    },
    metricsFilter=None, # {'ndcg', 'ndcg@10'},
    sortBy='ndcg',
)
# Out:
# These values are common to all rows:
#
# 	- useExtraNews: False
# 	- lowercase: True
# 	- model: nmf
# 	- implementation: sklearn-nmf
# 	- nmfL1Ratio: 0
# 	- nmfAlpha: 0.1
# 	- distance: cosine
# 	- splitVersion: 2
# 	- maxUsers: None
# 	- maxDF: 300
# 	- minDF: 0.0005
# 	- nmfInit: nndsvd
#           id  doLemmatization historyRef  maxDocuments  maxIter  nbTopics  \
# 0  nmf-330c8            False         30         10000      200       100
# 1  nmf-b61b9             True        0.5          1000      100        30
# 2  nmf-09f9c             True        0.3          1000      200        30
# 3  nmf-dea50             True        0.3         10000      200        30
#
#         map       mrr      ndcg   ndcg@10  ndcg@100      p@10     p@100
# 0  0.234911  0.446258  0.489016  0.291090  0.415755  0.182861  0.048848
# 1  0.150380  0.318810  0.409265  0.186974  0.317141  0.122490  0.042544
# 2  0.149538  0.311292  0.407733  0.184111  0.316140  0.121553  0.042904
# 3  0.145358  0.304368  0.403756  0.177553  0.312424  0.117642  0.043049
