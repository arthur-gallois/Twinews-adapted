# %% [markdown]
# This notebook allow you to print results of models in tables

# %%
# from twinews import config as twinewsConf
# twinewsConf.mongoLocation = "octods"

# %%
from systemtools.hayj import *
from systemtools.location import *
from systemtools.basics import *
from systemtools.file import *
from systemtools.printer import *
from twinews.utils import *
from twinews.evaluation.utils import *
from twinews.models.ranking import *

# %%
if False:
    purgeSubsampledRankings()

# %%
if False:
    removeRankingsAndScores('tfidf-b0e81')

# %%
def basicPrint(model, *args, b=None, w=None, splitVersion=2, **kwargs):
    if w is not None and isinstance(w, str):
        w = [w]
    if b is not None and isinstance(b, str):
        b = [b]
    if w is not None and len(args) > 0:
        args = list(args) + list(w)
    printReportKwargs = \
    {
        'model': model,
        'splitVersion': splitVersion,
        'noSubsampling': True,
        'metaFilter': \
        {
            # "implementation": "gensim-lda",
        },
        # 'allowedMetrics': {'ndcg', 'div@100', 'topic-div@100', 'swjacc-div@100', 'jacc-div@100'}, # None, {'ndcg', 'ndcg@10'}
        'discardedMetrics': {'map', 'mrr', 'ndcg@10', 'ndcg@100', 'p@10', 'p@100'},
        'whiteMetricPatterns': None if len(args) == 0 else set(list(args) + ['ndcg']),
        'blackMetricPatterns': b,
        'sortBy': 'ndcg',
    }
    printReportKwargs = mergeDicts(printReportKwargs, kwargs)
    printReport(**printReportKwargs)

# %%
def printAll(*args, **kwargs):
    kwargs['onlyFields'] = {'id', 'model'}
    kwargs['excludedModels'] = {'combin', 'ideal', 'worst', 'random'}
    return basicPrint(None, *args, **kwargs)

# %% [markdown]
# # Misc

# %%
if False:
    twinewsRankings = getTwinewsRankings()
    keysToDelete = set()
    for key in twinewsRankings.keys():
        if "combin" in key:
            meta = twinewsRankings.getMeta(key)
            hasTFIDF = False
            for m in meta['models']:
                if 'tfidf' in m:
                    hasTFIDF = True
                    break
            if hasTFIDF and meta['splitVersion'] == 1:
                keysToDelete.add(key)
    print(keysToDelete)

# %%
if False:
    for key in keysToDelete:
        removeRankingsAndScores(key)

# %%
# Removing combin models with maxUsers is not None:
if False:
    twinewsRankings = getTwinewsRankings()
    ids = twinewsRankings.keys()
    bp(ids)
    for currentId in ids:
        if 'combin' in currentId:
            meta = twinewsRankings.getMeta(currentId)
            if meta['maxUsers'] is not None:
                del twinewsRankings[currentId]

# %% [markdown]
# # Model lists per split version

# %%
def printModelList(splitVersion):
    twinewsRankings = getTwinewsRankings()
    models = set()
    for key in twinewsRankings.keys():
        meta = twinewsRankings.getMeta(key)
        if meta["splitVersion"] == splitVersion:
            models.add(meta['model'])
    print(" ".join(sorted(list(models))) + " (" + str(len(models)) + ")")

# %%
printModelList(2)
# Out:
# BM25_yf DSSM_title DSSM_yf bert bm25 combin dbert-base dbert-ft doc2vec ideal infersent jaccard lda nmf random sent2vec stylo tfidf usent word2vec worst (21)

# %%
printModelList(1)
# Out:
# bert bm25 combin dbert-base dbert-ft doc2vec ideal infersent jaccard lda nmf random sent2vec stylo tfidf usent word2vec worst (18)

# %% [markdown]
# # Reference models

# %%
basicPrint('ideal', splitVersion=2)
basicPrint('random', splitVersion=2)
basicPrint('worst', splitVersion=2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-5cda2d8024a6> in <module>
# ----> 1 basicPrint('ideal', splitVersion=2)
#       2 basicPrint('random', splitVersion=2)
#       3 basicPrint('worst', splitVersion=2)
#
# <ipython-input-5-3da28327abff> in basicPrint(model, b, w, splitVersion, *args, **kwargs)
#      22     }
#      23     printReportKwargs = mergeDicts(printReportKwargs, kwargs)
# ---> 24     printReport(**printReportKwargs)
#
# ~/PycharmProjects/Twinews/twinews/evaluation/utils.py in printReport(model, excludedModels, onlyFields, splitVersion, metaFilter, allowedMetrics, discardedMetrics, blackMetricPatterns, whiteMetricPatterns, noSubsampling, logger, sortBy, colorize)
#     200                         if sortBy is not None and sortBy in metrics:
#     201                                 greenMetrics.remove(sortBy)
# --> 202                         df = colorise_df_columns(df, grey={'id'}, green=greenMetrics, blue=sortBy)
#     203                 display(df)
#     204                 return df
#
# ~/anaconda3/lib/python3.7/site-packages/dataviztools/pandasutils.py in colorise_df_columns(df, grey, blue, red, green, grey_rgba, green_rgba, blue_rgba, red_rgba)
#      40         for column in set(colors[color]):
#      41             if column not in df.columns:
# ---> 42                 colors[color].remove(column)
#      43     # We define the colorize funct:
#      44     def colorize(df):
#
# AttributeError: 'str' object has no attribute 'remove'

# %% [markdown]
# # Ad-hoc models

# %%
basicPrint('jaccard', 'div', b=['topic', 'jacc', 'style'])

# %%
basicPrint('bm25')
# Out:
# These values are common to all rows (26):
#
# 	- splitVersion: 2
# 	- model: bm25
# 	- maxUsers: None
# 	- epsilon: 0.25
# Normalized metrics: {'style-nov@100', 'topic-snov@100', 'snov@100', 'style-snov@100', 'topic-div@100', 'topic-nov@100', 'style-div@100', 'div@100', 'nov@100'}
# <style  type="text/css" >
#     #T_f67bdb92_afe2_11ea_8c90_ff1f58ea8accrow0_col0 {
#             background-color:  rgba(150, 150, 150, 0.3);
#         }    #T_f67bdb92_afe2_11ea_8c90_ff1f58ea8accrow0_col7 {
#             background-color:  rgba(0, 122, 204, 0.3);
#         }    #T_f67bdb92_afe2_11ea_8c90_ff1f58ea8accrow0_col8 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_f67bdb92_afe2_11ea_8c90_ff1f58ea8accrow0_col9 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_f67bdb92_afe2_11ea_8c90_ff1f58ea8accrow0_col10 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_f67bdb92_afe2_11ea_8c90_ff1f58ea8accrow0_col11 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_f67bdb92_afe2_11ea_8c90_ff1f58ea8accrow0_col12 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_f67bdb92_afe2_11ea_8c90_ff1f58ea8accrow0_col13 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_f67bdb92_afe2_11ea_8c90_ff1f58ea8accrow0_col14 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_f67bdb92_afe2_11ea_8c90_ff1f58ea8accrow0_col15 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_f67bdb92_afe2_11ea_8c90_ff1f58ea8accrow0_col16 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_f67bdb92_afe2_11ea_8c90_ff1f58ea8accrow0_col17 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_f67bdb92_afe2_11ea_8c90_ff1f58ea8accrow0_col18 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_f67bdb92_afe2_11ea_8c90_ff1f58ea8accrow0_col19 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_f67bdb92_afe2_11ea_8c90_ff1f58ea8accrow0_col20 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_f67bdb92_afe2_11ea_8c90_ff1f58ea8accrow0_col21 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_f67bdb92_afe2_11ea_8c90_ff1f58ea8accrow0_col22 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_f67bdb92_afe2_11ea_8c90_ff1f58ea8accrow0_col23 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_f67bdb92_afe2_11ea_8c90_ff1f58ea8accrow0_col24 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_f67bdb92_afe2_11ea_8c90_ff1f58ea8accrow0_col25 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_f67bdb92_afe2_11ea_8c90_ff1f58ea8accrow0_col26 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_f67bdb92_afe2_11ea_8c90_ff1f58ea8accrow0_col27 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_f67bdb92_afe2_11ea_8c90_ff1f58ea8accrow1_col0 {
#             background-color:  rgba(150, 150, 150, 0.3);
#         }    #T_f67bdb92_afe2_11ea_8c90_ff1f58ea8accrow1_col7 {
#             background-color:  rgba(0, 122, 204, 0.3);
#         }    #T_f67bdb92_afe2_11ea_8c90_ff1f58ea8accrow1_col8 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_f67bdb92_afe2_11ea_8c90_ff1f58ea8accrow1_col9 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_f67bdb92_afe2_11ea_8c90_ff1f58ea8accrow1_col10 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_f67bdb92_afe2_11ea_8c90_ff1f58ea8accrow1_col11 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_f67bdb92_afe2_11ea_8c90_ff1f58ea8accrow1_col12 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_f67bdb92_afe2_11ea_8c90_ff1f58ea8accrow1_col13 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_f67bdb92_afe2_11ea_8c90_ff1f58ea8accrow1_col14 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_f67bdb92_afe2_11ea_8c90_ff1f58ea8accrow1_col15 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_f67bdb92_afe2_11ea_8c90_ff1f58ea8accrow1_col16 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_f67bdb92_afe2_11ea_8c90_ff1f58ea8accrow1_col17 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_f67bdb92_afe2_11ea_8c90_ff1f58ea8accrow1_col18 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_f67bdb92_afe2_11ea_8c90_ff1f58ea8accrow1_col19 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_f67bdb92_afe2_11ea_8c90_ff1f58ea8accrow1_col20 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_f67bdb92_afe2_11ea_8c90_ff1f58ea8accrow1_col21 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_f67bdb92_afe2_11ea_8c90_ff1f58ea8accrow1_col22 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_f67bdb92_afe2_11ea_8c90_ff1f58ea8accrow1_col23 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_f67bdb92_afe2_11ea_8c90_ff1f58ea8accrow1_col24 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_f67bdb92_afe2_11ea_8c90_ff1f58ea8accrow1_col25 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_f67bdb92_afe2_11ea_8c90_ff1f58ea8accrow1_col26 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_f67bdb92_afe2_11ea_8c90_ff1f58ea8accrow1_col27 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_f67bdb92_afe2_11ea_8c90_ff1f58ea8accrow2_col0 {
#             background-color:  rgba(150, 150, 150, 0.3);
#         }    #T_f67bdb92_afe2_11ea_8c90_ff1f58ea8accrow2_col7 {
#             background-color:  rgba(0, 122, 204, 0.3);
#         }    #T_f67bdb92_afe2_11ea_8c90_ff1f58ea8accrow2_col8 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_f67bdb92_afe2_11ea_8c90_ff1f58ea8accrow2_col9 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_f67bdb92_afe2_11ea_8c90_ff1f58ea8accrow2_col10 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_f67bdb92_afe2_11ea_8c90_ff1f58ea8accrow2_col11 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_f67bdb92_afe2_11ea_8c90_ff1f58ea8accrow2_col12 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_f67bdb92_afe2_11ea_8c90_ff1f58ea8accrow2_col13 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_f67bdb92_afe2_11ea_8c90_ff1f58ea8accrow2_col14 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_f67bdb92_afe2_11ea_8c90_ff1f58ea8accrow2_col15 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_f67bdb92_afe2_11ea_8c90_ff1f58ea8accrow2_col16 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_f67bdb92_afe2_11ea_8c90_ff1f58ea8accrow2_col17 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_f67bdb92_afe2_11ea_8c90_ff1f58ea8accrow2_col18 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_f67bdb92_afe2_11ea_8c90_ff1f58ea8accrow2_col19 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_f67bdb92_afe2_11ea_8c90_ff1f58ea8accrow2_col20 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_f67bdb92_afe2_11ea_8c90_ff1f58ea8accrow2_col21 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_f67bdb92_afe2_11ea_8c90_ff1f58ea8accrow2_col22 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_f67bdb92_afe2_11ea_8c90_ff1f58ea8accrow2_col23 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_f67bdb92_afe2_11ea_8c90_ff1f58ea8accrow2_col24 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_f67bdb92_afe2_11ea_8c90_ff1f58ea8accrow2_col25 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_f67bdb92_afe2_11ea_8c90_ff1f58ea8accrow2_col26 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_f67bdb92_afe2_11ea_8c90_ff1f58ea8accrow2_col27 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_f67bdb92_afe2_11ea_8c90_ff1f58ea8accrow3_col0 {

# %%
basicPrint('BM25_yf', noSubsampling=False)
# Out:
# Found key difference: {'empiricalParameter'}
# These values are common to all rows (7):
#
# 	- epsilon: 0.25
# 	- lowercase: False
# 	- maxDF: 300
# 	- splitVersion: 2
# 	- maxDocuments: 10000
# 	- doLemmatization: True
# 	- useExtraNews: False
# 	- minDF: 0.0005
# 	- model: BM25_yf
# 	- implementation: BM25
# Normalized metrics: {'style-snov@100', 'snov@100', 'div@100', 'nov@100', 'style-nov@100', 'topic-snov@100', 'style-div@100', 'topic-div@100', 'topic-nov@100'}
# <style  type="text/css" >
#     #T_f232fb6c_bbd4_11ea_b4e6_db645e0fc947row0_col0 {
#             background-color:  rgba(150, 150, 150, 0.3);
#         }    #T_f232fb6c_bbd4_11ea_b4e6_db645e0fc947row0_col5 {
#             background-color:  rgba(0, 122, 204, 0.3);
#         }    #T_f232fb6c_bbd4_11ea_b4e6_db645e0fc947row0_col6 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_f232fb6c_bbd4_11ea_b4e6_db645e0fc947row0_col7 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_f232fb6c_bbd4_11ea_b4e6_db645e0fc947row0_col8 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_f232fb6c_bbd4_11ea_b4e6_db645e0fc947row0_col9 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_f232fb6c_bbd4_11ea_b4e6_db645e0fc947row0_col10 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_f232fb6c_bbd4_11ea_b4e6_db645e0fc947row0_col11 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_f232fb6c_bbd4_11ea_b4e6_db645e0fc947row0_col12 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_f232fb6c_bbd4_11ea_b4e6_db645e0fc947row0_col13 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_f232fb6c_bbd4_11ea_b4e6_db645e0fc947row0_col14 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_f232fb6c_bbd4_11ea_b4e6_db645e0fc947row0_col15 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_f232fb6c_bbd4_11ea_b4e6_db645e0fc947row0_col16 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_f232fb6c_bbd4_11ea_b4e6_db645e0fc947row0_col17 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_f232fb6c_bbd4_11ea_b4e6_db645e0fc947row0_col18 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_f232fb6c_bbd4_11ea_b4e6_db645e0fc947row0_col19 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_f232fb6c_bbd4_11ea_b4e6_db645e0fc947row0_col20 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_f232fb6c_bbd4_11ea_b4e6_db645e0fc947row0_col21 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_f232fb6c_bbd4_11ea_b4e6_db645e0fc947row0_col22 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_f232fb6c_bbd4_11ea_b4e6_db645e0fc947row0_col23 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_f232fb6c_bbd4_11ea_b4e6_db645e0fc947row0_col24 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_f232fb6c_bbd4_11ea_b4e6_db645e0fc947row0_col25 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_f232fb6c_bbd4_11ea_b4e6_db645e0fc947row1_col0 {
#             background-color:  rgba(150, 150, 150, 0.3);
#         }    #T_f232fb6c_bbd4_11ea_b4e6_db645e0fc947row1_col5 {
#             background-color:  rgba(0, 122, 204, 0.3);
#         }    #T_f232fb6c_bbd4_11ea_b4e6_db645e0fc947row1_col6 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_f232fb6c_bbd4_11ea_b4e6_db645e0fc947row1_col7 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_f232fb6c_bbd4_11ea_b4e6_db645e0fc947row1_col8 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_f232fb6c_bbd4_11ea_b4e6_db645e0fc947row1_col9 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_f232fb6c_bbd4_11ea_b4e6_db645e0fc947row1_col10 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_f232fb6c_bbd4_11ea_b4e6_db645e0fc947row1_col11 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_f232fb6c_bbd4_11ea_b4e6_db645e0fc947row1_col12 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_f232fb6c_bbd4_11ea_b4e6_db645e0fc947row1_col13 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_f232fb6c_bbd4_11ea_b4e6_db645e0fc947row1_col14 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_f232fb6c_bbd4_11ea_b4e6_db645e0fc947row1_col15 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_f232fb6c_bbd4_11ea_b4e6_db645e0fc947row1_col16 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_f232fb6c_bbd4_11ea_b4e6_db645e0fc947row1_col17 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_f232fb6c_bbd4_11ea_b4e6_db645e0fc947row1_col18 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_f232fb6c_bbd4_11ea_b4e6_db645e0fc947row1_col19 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_f232fb6c_bbd4_11ea_b4e6_db645e0fc947row1_col20 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_f232fb6c_bbd4_11ea_b4e6_db645e0fc947row1_col21 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_f232fb6c_bbd4_11ea_b4e6_db645e0fc947row1_col22 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_f232fb6c_bbd4_11ea_b4e6_db645e0fc947row1_col23 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_f232fb6c_bbd4_11ea_b4e6_db645e0fc947row1_col24 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_f232fb6c_bbd4_11ea_b4e6_db645e0fc947row1_col25 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_f232fb6c_bbd4_11ea_b4e6_db645e0fc947row2_col0 {
#             background-color:  rgba(150, 150, 150, 0.3);
#         }    #T_f232fb6c_bbd4_11ea_b4e6_db645e0fc947row2_col5 {
#             background-color:  rgba(0, 122, 204, 0.3);
#         }    #T_f232fb6c_bbd4_11ea_b4e6_db645e0fc947row2_col6 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_f232fb6c_bbd4_11ea_b4e6_db645e0fc947row2_col7 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_f232fb6c_bbd4_11ea_b4e6_db645e0fc947row2_col8 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_f232fb6c_bbd4_11ea_b4e6_db645e0fc947row2_col9 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_f232fb6c_bbd4_11ea_b4e6_db645e0fc947row2_col10 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_f232fb6c_bbd4_11ea_b4e6_db645e0fc947row2_col11 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_f232fb6c_bbd4_11ea_b4e6_db645e0fc947row2_col12 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_f232fb6c_bbd4_11ea_b4e6_db645e0fc947row2_col13 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_f232fb6c_bbd4_11ea_b4e6_db645e0fc947row2_col14 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_f232fb6c_bbd4_11ea_b4e6_db645e0fc947row2_col15 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_f232fb6c_bbd4_11ea_b4e6_db645e0fc947row2_col16 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_f232fb6c_bbd4_11ea_b4e6_db645e0fc947row2_col17 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_f232fb6c_bbd4_11ea_b4e6_db645e0fc947row2_col18 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_f232fb6c_bbd4_11ea_b4e6_db645e0fc947row2_col19 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_f232fb6c_bbd4_11ea_b4e6_db645e0fc947row2_col20 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_f232fb6c_bbd4_11ea_b4e6_db645e0fc947row2_col21 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_f232fb6c_bbd4_11ea_b4e6_db645e0fc947row2_col22 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_f232fb6c_bbd4_11ea_b4e6_db645e0fc947row2_col23 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_f232fb6c_bbd4_11ea_b4e6_db645e0fc947row2_col24 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_f232fb6c_bbd4_11ea_b4e6_db645e0fc947row2_col25 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_f232fb6c_bbd4_11ea_b4e6_db645e0fc947row3_col0 {

# %%
basicPrint('DSSM_yf', noSubsampling=False)
# Out:
# Found key difference: {'historyRef', 'char_embedding_size'}
# These values are common to all rows (2):
#
# 	- learning_rate: 0.0005
# 	- keep_prob: 0.7
# 	- class_size: 2
# 	- splitVersion: 2
# 	- useExtraNews: 0
# 	- model: DSSM_yf
# 	- similarity: cosine
# Normalized metrics: {'style-snov@100', 'snov@100', 'div@100', 'nov@100', 'style-nov@100', 'topic-snov@100', 'style-div@100', 'topic-div@100', 'topic-nov@100'}
# <style  type="text/css" >
#     #T_fb425af4_bbd4_11ea_b4e6_db645e0fc947row0_col0 {
#             background-color:  rgba(150, 150, 150, 0.3);
#         }    #T_fb425af4_bbd4_11ea_b4e6_db645e0fc947row0_col13 {
#             background-color:  rgba(0, 122, 204, 0.3);
#         }    #T_fb425af4_bbd4_11ea_b4e6_db645e0fc947row0_col14 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_fb425af4_bbd4_11ea_b4e6_db645e0fc947row0_col15 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_fb425af4_bbd4_11ea_b4e6_db645e0fc947row0_col16 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_fb425af4_bbd4_11ea_b4e6_db645e0fc947row0_col17 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_fb425af4_bbd4_11ea_b4e6_db645e0fc947row0_col18 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_fb425af4_bbd4_11ea_b4e6_db645e0fc947row0_col19 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_fb425af4_bbd4_11ea_b4e6_db645e0fc947row0_col20 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_fb425af4_bbd4_11ea_b4e6_db645e0fc947row0_col21 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_fb425af4_bbd4_11ea_b4e6_db645e0fc947row0_col22 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_fb425af4_bbd4_11ea_b4e6_db645e0fc947row0_col23 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_fb425af4_bbd4_11ea_b4e6_db645e0fc947row0_col24 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_fb425af4_bbd4_11ea_b4e6_db645e0fc947row0_col25 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_fb425af4_bbd4_11ea_b4e6_db645e0fc947row0_col26 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_fb425af4_bbd4_11ea_b4e6_db645e0fc947row0_col27 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_fb425af4_bbd4_11ea_b4e6_db645e0fc947row0_col28 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_fb425af4_bbd4_11ea_b4e6_db645e0fc947row0_col29 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_fb425af4_bbd4_11ea_b4e6_db645e0fc947row0_col30 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_fb425af4_bbd4_11ea_b4e6_db645e0fc947row0_col31 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_fb425af4_bbd4_11ea_b4e6_db645e0fc947row0_col32 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_fb425af4_bbd4_11ea_b4e6_db645e0fc947row0_col33 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_fb425af4_bbd4_11ea_b4e6_db645e0fc947row1_col0 {
#             background-color:  rgba(150, 150, 150, 0.3);
#         }    #T_fb425af4_bbd4_11ea_b4e6_db645e0fc947row1_col13 {
#             background-color:  rgba(0, 122, 204, 0.3);
#         }    #T_fb425af4_bbd4_11ea_b4e6_db645e0fc947row1_col14 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_fb425af4_bbd4_11ea_b4e6_db645e0fc947row1_col15 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_fb425af4_bbd4_11ea_b4e6_db645e0fc947row1_col16 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_fb425af4_bbd4_11ea_b4e6_db645e0fc947row1_col17 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_fb425af4_bbd4_11ea_b4e6_db645e0fc947row1_col18 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_fb425af4_bbd4_11ea_b4e6_db645e0fc947row1_col19 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_fb425af4_bbd4_11ea_b4e6_db645e0fc947row1_col20 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_fb425af4_bbd4_11ea_b4e6_db645e0fc947row1_col21 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_fb425af4_bbd4_11ea_b4e6_db645e0fc947row1_col22 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_fb425af4_bbd4_11ea_b4e6_db645e0fc947row1_col23 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_fb425af4_bbd4_11ea_b4e6_db645e0fc947row1_col24 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_fb425af4_bbd4_11ea_b4e6_db645e0fc947row1_col25 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_fb425af4_bbd4_11ea_b4e6_db645e0fc947row1_col26 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_fb425af4_bbd4_11ea_b4e6_db645e0fc947row1_col27 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_fb425af4_bbd4_11ea_b4e6_db645e0fc947row1_col28 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_fb425af4_bbd4_11ea_b4e6_db645e0fc947row1_col29 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_fb425af4_bbd4_11ea_b4e6_db645e0fc947row1_col30 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_fb425af4_bbd4_11ea_b4e6_db645e0fc947row1_col31 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_fb425af4_bbd4_11ea_b4e6_db645e0fc947row1_col32 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }    #T_fb425af4_bbd4_11ea_b4e6_db645e0fc947row1_col33 {
#             background-color:  rgba(0, 155, 149, 0.3);
#         }</style><table id="T_fb425af4_bbd4_11ea_b4e6_db645e0fc947" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >id</th>        <th class="col_heading level0 col1" >maxUsers</th>        <th class="col_heading level0 col2" >maxDocuments</th>        <th class="col_heading level0 col3" >minDF</th>        <th class="col_heading level0 col4" >maxDF</th>        <th class="col_heading level0 col5" >lowercase</th>        <th class="col_heading level0 col6" >doLemmatization</th>        <th class="col_heading level0 col7" >seq_length</th>        <th class="col_heading level0 col8" >char_embedding_size</th>        <th class="col_heading level0 col9" >vocab_size</th>        <th class="col_heading level0 col10" >epochs</th>        <th class="col_heading level0 col11" >batch_size</th>        <th class="col_heading level0 col12" >historyRef</th>        <th class="col_heading level0 col13" >ndcg</th>        <th class="col_heading level0 col14" >div@100</th>        <th class="col_heading level0 col15" >topic-div@100</th>        <th class="col_heading level0 col16" >jacc-div@100</th>        <th class="col_heading level0 col17" >swjacc-div@100</th>        <th class="col_heading level0 col18" >style-div@100</th>        <th class="col_heading level0 col19" >nov@100</th>        <th class="col_heading level0 col20" >topic-nov@100</th>        <th class="col_heading level0 col21" >jacc-nov@100</th>        <th class="col_heading level0 col22" >swjacc-nov@100</th>        <th class="col_heading level0 col23" >style-nov@100</th>        <th class="col_heading level0 col24" >snov@100</th>        <th class="col_heading level0 col25" >topic-snov@100</th>        <th class="col_heading level0 col26" >jacc-snov@100</th>        <th class="col_heading level0 col27" >swjacc-snov@100</th>        <th class="col_heading level0 col28" >style-snov@100</th>        <th class="col_heading level0 col29" >tfidf-ser@100</th>        <th class="col_heading level0 col30" >wtfidf-ser@100</th>        <th class="col_heading level0 col31" >bm25-ser@100</th>        <th class="col_heading level0 col32" >jacc-ser@100</th>        <th class="col_heading level0 col33" >style-ser@100</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_fb425af4_bbd4_11ea_b4e6_db645e0fc947level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_fb425af4_bbd4_11ea_b4e6_db645e0fc947row0_col0" class="data row0 col0" >DSSM_yf-d9604</td>
#                         <td id="T_fb425af4_bbd4_11ea_b4e6_db645e0fc947row0_col1" class="data row0 col1" >10</td>
#                         <td id="T_fb425af4_bbd4_11ea_b4e6_db645e0fc947row0_co

# %% [markdown]
# # Models that use vector representations

# %%
basicPrint('lda')

# %%
basicPrint('nmf')

# %%
basicPrint('tfidf')

# %%
basicPrint('dbert-ft')

# %%
basicPrint('dbert-base')

# %%
basicPrint('stylo')

# %%
basicPrint('infersent')

# %%
basicPrint('sent2vec')

# %%
basicPrint('word2vec')

# %%
basicPrint('doc2vec')

# %%
basicPrint('usent')

# %%
basicPrint('bert')

# %% [markdown]
# # All models for split version 2

# %%
printAll('div', splitVersion=2)

# %% [markdown]
# # Combinations of models

# %%
# Expected 156 rows:
basicPrint('combin')

# %% [markdown]
# # Deep Learning models

# %%
basicPrint('Convnet', noSubsampling=False)
# Out:
# These values are common to all rows (7):
#
# 	- epochs: 100
# 	- lowercase: True
# 	- maxDF: 20
# 	- splitVersion: 2
# 	- maxDocuments: None
# 	- doLemmatization: True
# 	- class_size: 2
# 	- useExtraNews: 0
# 	- learning_rate: 0.0005
# 	- keep_prob: 0.7
# 	- similarity: cosine
# 	- minDF: 0.0005
# 	- vocab_size: 3029
# 	- model: Convnet
# 	- batch_size: 1000
# 	- seq_length: 100
# <style  type="text/css" >
#     #T_ba1002c4_bf63_11ea_b4e6_db645e0fc947row0_col0 {
#             background-color:  rgba(150, 150, 150, 0.3);
#         }    #T_ba1002c4_bf63_11ea_b4e6_db645e0fc947row0_col2 {
#             background-color:  rgba(0, 122, 204, 0.3);
#         }    #T_ba1002c4_bf63_11ea_b4e6_db645e0fc947row1_col0 {
#             background-color:  rgba(150, 150, 150, 0.3);
#         }    #T_ba1002c4_bf63_11ea_b4e6_db645e0fc947row1_col2 {
#             background-color:  rgba(0, 122, 204, 0.3);
#         }    #T_ba1002c4_bf63_11ea_b4e6_db645e0fc947row2_col0 {
#             background-color:  rgba(150, 150, 150, 0.3);
#         }    #T_ba1002c4_bf63_11ea_b4e6_db645e0fc947row2_col2 {
#             background-color:  rgba(0, 122, 204, 0.3);
#         }    #T_ba1002c4_bf63_11ea_b4e6_db645e0fc947row3_col0 {
#             background-color:  rgba(150, 150, 150, 0.3);
#         }    #T_ba1002c4_bf63_11ea_b4e6_db645e0fc947row3_col2 {
#             background-color:  rgba(0, 122, 204, 0.3);
#         }    #T_ba1002c4_bf63_11ea_b4e6_db645e0fc947row4_col0 {
#             background-color:  rgba(150, 150, 150, 0.3);
#         }    #T_ba1002c4_bf63_11ea_b4e6_db645e0fc947row4_col2 {
#             background-color:  rgba(0, 122, 204, 0.3);
#         }    #T_ba1002c4_bf63_11ea_b4e6_db645e0fc947row5_col0 {
#             background-color:  rgba(150, 150, 150, 0.3);
#         }    #T_ba1002c4_bf63_11ea_b4e6_db645e0fc947row5_col2 {
#             background-color:  rgba(0, 122, 204, 0.3);
#         }    #T_ba1002c4_bf63_11ea_b4e6_db645e0fc947row6_col0 {
#             background-color:  rgba(150, 150, 150, 0.3);
#         }    #T_ba1002c4_bf63_11ea_b4e6_db645e0fc947row6_col2 {
#             background-color:  rgba(0, 122, 204, 0.3);
#         }</style><table id="T_ba1002c4_bf63_11ea_b4e6_db645e0fc947" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >id</th>        <th class="col_heading level0 col1" >maxUsers</th>        <th class="col_heading level0 col2" >ndcg</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ba1002c4_bf63_11ea_b4e6_db645e0fc947level0_row0" class="row_heading level0 row0" >3</th>
#                         <td id="T_ba1002c4_bf63_11ea_b4e6_db645e0fc947row0_col0" class="data row0 col0" >Convnet-e441e</td>
#                         <td id="T_ba1002c4_bf63_11ea_b4e6_db645e0fc947row0_col1" class="data row0 col1" >10</td>
#                         <td id="T_ba1002c4_bf63_11ea_b4e6_db645e0fc947row0_col2" class="data row0 col2" >0.24208</td>
#             </tr>
#             <tr>
#                         <th id="T_ba1002c4_bf63_11ea_b4e6_db645e0fc947level0_row1" class="row_heading level0 row1" >0</th>
#                         <td id="T_ba1002c4_bf63_11ea_b4e6_db645e0fc947row1_col0" class="data row1 col0" >Convnet-8d315</td>
#                         <td id="T_ba1002c4_bf63_11ea_b4e6_db645e0fc947row1_col1" class="data row1 col1" >50</td>
#                         <td id="T_ba1002c4_bf63_11ea_b4e6_db645e0fc947row1_col2" class="data row1 col2" >0.23837</td>
#             </tr>
#             <tr>
#                         <th id="T_ba1002c4_bf63_11ea_b4e6_db645e0fc947level0_row2" class="row_heading level0 row2" >1</th>
#                         <td id="T_ba1002c4_bf63_11ea_b4e6_db645e0fc947row2_col0" class="data row2 col0" >Convnet-23539</td>
#                         <td id="T_ba1002c4_bf63_11ea_b4e6_db645e0fc947row2_col1" class="data row2 col1" >100</td>
#                         <td id="T_ba1002c4_bf63_11ea_b4e6_db645e0fc947row2_col2" class="data row2 col2" >0.23572</td>
#             </tr>
#             <tr>
#                         <th id="T_ba1002c4_bf63_11ea_b4e6_db645e0fc947level0_row3" class="row_heading level0 row3" >2</th>
#                         <td id="T_ba1002c4_bf63_11ea_b4e6_db645e0fc947row3_col0" class="data row3 col0" >Convnet-e9eb0</td>
#                         <td id="T_ba1002c4_bf63_11ea_b4e6_db645e0fc947row3_col1" class="data row3 col1" >200</td>
#                         <td id="T_ba1002c4_bf63_11ea_b4e6_db645e0fc947row3_col2" class="data row3 col2" >0.23368</td>
#             </tr>
#             <tr>
#                         <th id="T_ba1002c4_bf63_11ea_b4e6_db645e0fc947level0_row4" class="row_heading level0 row4" >5</th>
#                         <td id="T_ba1002c4_bf63_11ea_b4e6_db645e0fc947row4_col0" class="data row4 col0" >Convnet-63cf6</td>
#                         <td id="T_ba1002c4_bf63_11ea_b4e6_db645e0fc947row4_col1" class="data row4 col1" >500</td>
#                         <td id="T_ba1002c4_bf63_11ea_b4e6_db645e0fc947row4_col2" class="data row4 col2" >0.23203</td>
#             </tr>
#             <tr>
#                         <th id="T_ba1002c4_bf63_11ea_b4e6_db645e0fc947level0_row5" class="row_heading level0 row5" >4</th>
#                         <td id="T_ba1002c4_bf63_11ea_b4e6_db645e0fc947row5_col0" class="data row5 col0" >Convnet-d511f</td>
#                         <td id="T_ba1002c4_bf63_11ea_b4e6_db645e0fc947row5_col1" class="data row5 col1" >30</td>
#                         <td id="T_ba1002c4_bf63_11ea_b4e6_db645e0fc947row5_col2" class="data row5 col2" >0.22954</td>
#             </tr>
#             <tr>
#                         <th id="T_ba1002c4_bf63_11ea_b4e6_db645e0fc947level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_ba1002c4_bf63_11ea_b4e6_db645e0fc947row6_col0" class="data row6 col0" >Convnet-49dfd</td>
#                         <td id="T_ba1002c4_bf63_11ea_b4e6_db645e0fc947row6_col1" class="data row6 col1" >300</td>
#                         <td id="T_ba1002c4_bf63_11ea_b4e6_db645e0fc947row6_col2" class="data row6 col2" >0.229</td>
#             </tr>
#     </tbody></table>

# %%
basicPrint('DSSM_title', noSubsampling=False)
# Out:
# Found key difference: {'testVersion'}
# Found key difference: {'testVersion'}
# Found key difference: {'testVersion'}
# These values are common to all rows (7):
#
# 	- epochs: 100
# 	- learning_rate: 0.0005
# 	- keep_prob: 0.7
# 	- batch_size: 1000
# 	- maxDF: 20
# 	- vocab_size: 3029
# 	- lowercase: True
# 	- class_size: 2
# 	- splitVersion: 2
# 	- useExtraNews: 0
# 	- minDF: 0.0005
# 	- seq_length: 100
# 	- model: DSSM_title
# 	- similarity: cosine
# <style  type="text/css" >
#     #T_4c6d679a_bc9b_11ea_b4e6_db645e0fc947row0_col0 {
#             background-color:  rgba(150, 150, 150, 0.3);
#         }    #T_4c6d679a_bc9b_11ea_b4e6_db645e0fc947row0_col5 {
#             background-color:  rgba(0, 122, 204, 0.3);
#         }    #T_4c6d679a_bc9b_11ea_b4e6_db645e0fc947row1_col0 {
#             background-color:  rgba(150, 150, 150, 0.3);
#         }    #T_4c6d679a_bc9b_11ea_b4e6_db645e0fc947row1_col5 {
#             background-color:  rgba(0, 122, 204, 0.3);
#         }    #T_4c6d679a_bc9b_11ea_b4e6_db645e0fc947row2_col0 {
#             background-color:  rgba(150, 150, 150, 0.3);
#         }    #T_4c6d679a_bc9b_11ea_b4e6_db645e0fc947row2_col5 {
#             background-color:  rgba(0, 122, 204, 0.3);
#         }    #T_4c6d679a_bc9b_11ea_b4e6_db645e0fc947row3_col0 {
#             background-color:  rgba(150, 150, 150, 0.3);
#         }    #T_4c6d679a_bc9b_11ea_b4e6_db645e0fc947row3_col5 {
#             background-color:  rgba(0, 122, 204, 0.3);
#         }    #T_4c6d679a_bc9b_11ea_b4e6_db645e0fc947row4_col0 {
#             background-color:  rgba(150, 150, 150, 0.3);
#         }    #T_4c6d679a_bc9b_11ea_b4e6_db645e0fc947row4_col5 {
#             background-color:  rgba(0, 122, 204, 0.3);
#         }    #T_4c6d679a_bc9b_11ea_b4e6_db645e0fc947row5_col0 {
#             background-color:  rgba(150, 150, 150, 0.3);
#         }    #T_4c6d679a_bc9b_11ea_b4e6_db645e0fc947row5_col5 {
#             background-color:  rgba(0, 122, 204, 0.3);
#         }    #T_4c6d679a_bc9b_11ea_b4e6_db645e0fc947row6_col0 {
#             background-color:  rgba(150, 150, 150, 0.3);
#         }    #T_4c6d679a_bc9b_11ea_b4e6_db645e0fc947row6_col5 {
#             background-color:  rgba(0, 122, 204, 0.3);
#         }</style><table id="T_4c6d679a_bc9b_11ea_b4e6_db645e0fc947" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >id</th>        <th class="col_heading level0 col1" >maxUsers</th>        <th class="col_heading level0 col2" >maxDocuments</th>        <th class="col_heading level0 col3" >doLemmatization</th>        <th class="col_heading level0 col4" >testVersion</th>        <th class="col_heading level0 col5" >ndcg</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4c6d679a_bc9b_11ea_b4e6_db645e0fc947level0_row0" class="row_heading level0 row0" >4</th>
#                         <td id="T_4c6d679a_bc9b_11ea_b4e6_db645e0fc947row0_col0" class="data row0 col0" >DSSM_title-77b25</td>
#                         <td id="T_4c6d679a_bc9b_11ea_b4e6_db645e0fc947row0_col1" class="data row0 col1" >100</td>
#                         <td id="T_4c6d679a_bc9b_11ea_b4e6_db645e0fc947row0_col2" class="data row0 col2" >nan</td>
#                         <td id="T_4c6d679a_bc9b_11ea_b4e6_db645e0fc947row0_col3" class="data row0 col3" >True</td>
#                         <td id="T_4c6d679a_bc9b_11ea_b4e6_db645e0fc947row0_col4" class="data row0 col4" >2</td>
#                         <td id="T_4c6d679a_bc9b_11ea_b4e6_db645e0fc947row0_col5" class="data row0 col5" >0.24075</td>
#             </tr>
#             <tr>
#                         <th id="T_4c6d679a_bc9b_11ea_b4e6_db645e0fc947level0_row1" class="row_heading level0 row1" >2</th>
#                         <td id="T_4c6d679a_bc9b_11ea_b4e6_db645e0fc947row1_col0" class="data row1 col0" >DSSM_title-85ada</td>
#                         <td id="T_4c6d679a_bc9b_11ea_b4e6_db645e0fc947row1_col1" class="data row1 col1" >30</td>
#                         <td id="T_4c6d679a_bc9b_11ea_b4e6_db645e0fc947row1_col2" class="data row1 col2" >nan</td>
#                         <td id="T_4c6d679a_bc9b_11ea_b4e6_db645e0fc947row1_col3" class="data row1 col3" >True</td>
#                         <td id="T_4c6d679a_bc9b_11ea_b4e6_db645e0fc947row1_col4" class="data row1 col4" >2</td>
#                         <td id="T_4c6d679a_bc9b_11ea_b4e6_db645e0fc947row1_col5" class="data row1 col5" >0.23736</td>
#             </tr>
#             <tr>
#                         <th id="T_4c6d679a_bc9b_11ea_b4e6_db645e0fc947level0_row2" class="row_heading level0 row2" >6</th>
#                         <td id="T_4c6d679a_bc9b_11ea_b4e6_db645e0fc947row2_col0" class="data row2 col0" >DSSM_title-be85e</td>
#                         <td id="T_4c6d679a_bc9b_11ea_b4e6_db645e0fc947row2_col1" class="data row2 col1" >200</td>
#                         <td id="T_4c6d679a_bc9b_11ea_b4e6_db645e0fc947row2_col2" class="data row2 col2" >nan</td>
#                         <td id="T_4c6d679a_bc9b_11ea_b4e6_db645e0fc947row2_col3" class="data row2 col3" >True</td>
#                         <td id="T_4c6d679a_bc9b_11ea_b4e6_db645e0fc947row2_col4" class="data row2 col4" >2</td>
#                         <td id="T_4c6d679a_bc9b_11ea_b4e6_db645e0fc947row2_col5" class="data row2 col5" >0.23604</td>
#             </tr>
#             <tr>
#                         <th id="T_4c6d679a_bc9b_11ea_b4e6_db645e0fc947level0_row3" class="row_heading level0 row3" >0</th>
#                         <td id="T_4c6d679a_bc9b_11ea_b4e6_db645e0fc947row3_col0" class="data row3 col0" >DSSM_title-b11e8</td>
#                         <td id="T_4c6d679a_bc9b_11ea_b4e6_db645e0fc947row3_col1" class="data row3 col1" >200</td>
#                         <td id="T_4c6d679a_bc9b_11ea_b4e6_db645e0fc947row3_col2" class="data row3 col2" >nan</td>
#                         <td id="T_4c6d679a_bc9b_11ea_b4e6_db645e0fc947row3_col3" class="data row3 col3" >True</td>
#                         <td id="T_4c6d679a_bc9b_11ea_b4e6_db645e0fc947row3_col4" class="data row3 col4" >N/A</td>
#                         <td id="T_4c6d679a_bc9b_11ea_b4e6_db645e0fc947row3_col5" class="data row3 col5" >0.21806</td>
#             </tr>
#             <tr>
#                         <th id="T_4c6d679a_bc9b_11ea_b4e6_db645e0fc947level0_row4" class="row_heading level0 row4" >5</th>
#                         <td id="T_4c6d679a_bc9b_11ea_b4e6_db645e0fc947row4_col0" class="data row4 col0" >DSSM_title-e12fc</td>
#                         <td id="T_4c6d679a_bc9b_11ea_b4e6_db645e0fc947row4_col1" class="data row4 col1" >100</td>
#                         <td id="T_4c6d679a_bc9b_11ea_b4e6_db645e0fc947row4_col2" class="data row4 col2" >nan</td>
#                         <td id="T_4c6d679a_bc9b_11ea_b4e6_db645e0fc947row4_col3" class="data row4 col3" >True</td>
#                         <td id="T_4c6d679a_bc9b_11ea_b4e6_db645e0fc947row4_col4" class="data row4 col4" >N/A</td>
#                         <td id="T_4c6d679a_bc9b_11ea_b4e6_db645e0fc947row4_col5" class="data row4 col5" >0.21719</td>
#             </tr>
#             <tr>
#                         <th id="T_4c6d679a_bc9b_11ea_b4e6_db645e0fc947level0_row5" class="row_heading level0 row5" >1</th>
#                         <td id="T_4c6d679a_bc9b_11ea_b4e6_db645e0fc947row5_col0" class="data row5 col0" >DSSM_title-2e633</td>
#                         <td id="T_4c6d679a_bc9b_11ea_b4e6_db645e0fc947row5_col1" class="data row5 col1" >50</td>
#                         <td id="T_4c6d679a_bc9b_11ea_b4e6_db645e0fc947row5_col2" class="data row5 col2" >nan</td>
#                         <td id="T_4c6d679a_bc9b_11ea_b4e6_db645e0fc947row5_col3" class="data row5 col3" >True</td>
#                         <td id="T_4c6d679a_bc9b_11ea_b4e6_db645e0fc947row5_col4" class="data row5 col4" >N/A</td>
#                         <td id="T_4c6d679a_bc9b_11ea_b4e6_db645e0fc947row5_col5" class="data row5 col5" >0.2163</td>
#             </tr>
#             <tr>
#                         <th id="T_4c6d679a_bc9b_11ea_b4e6_db645e0fc947level0_row6" class="row_heading level0 row6" >3</th>
#                         <td id="T_4c6d679a_bc9b_11ea_b4e6_db645e0fc947row6_col0" class="data row6 col0" >DSSM_title-43ade</td>
#                         <td id="T_4c6d679a_bc9b_11ea_b4e6_db645e0fc947row6_col1" class="data row6 col1" >30</td>
#                         <td id="T_4c6d679a_bc9b_11ea_b4e6_db645e0fc947row6_col2" class="data row6 col2" >10000</td>
#                         <td id="T_4c6d679a_bc9b_11ea_b4e6_db645e0fc947row6_col3" class="data row6 col3" >False</td>
#                         <td id="T_4c

# %% [markdown]
# # Reports on the test set (split version 1)

# %%
basicPrint('ideal', splitVersion=1)
basicPrint('random', splitVersion=1)
basicPrint('worst', splitVersion=1)

# %%
printAll('div', splitVersion=1, doNormalization=True)

# %%
basicPrint('combin', 'nov', splitVersion=1)
